# %% [markdown]
# # importing the libraries

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # importing  the data set

# %%
df = pd.read_csv(r"C:\Users\heena\Downloads\car_df_EDA.csv")

# %%
df.head() # first 5 rows of column
# Out:
#    Unnamed: 0.1  Unnamed: 0         make fuel_type aspiration num_of_doors  \
# 0             0           1  alfa-romero       gas        std          two
# 1             1           2  alfa-romero       gas        std          two
# 2             2           3  alfa-romero       gas        std          two
# 3             3           4         audi       gas        std         four
# 4             4           5         audi       gas        std         four
#
#     body_style drive_wheels engine_location  wheel_base  ...  engine_type  \
# 0  convertible          rwd           front        88.6  ...         dohc
# 1  convertible          rwd           front        88.6  ...         dohc
# 2    hatchback          rwd           front        94.5  ...         ohcv
# 3        sedan          fwd           front        99.8  ...          ohc
# 4        sedan          4wd           front        99.4  ...          ohc
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 208 entries, 0 to 207
# Data columns (total 24 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0.1       208 non-null    int64
#  1   Unnamed: 0         208 non-null    int64
#  2   make               208 non-null    object
#  3   fuel_type          208 non-null    object
#  4   aspiration         208 non-null    object
#  5   num_of_doors       208 non-null    object
#  6   body_style         208 non-null    object
#  7   drive_wheels       208 non-null    object
#  8   engine_location    208 non-null    object
#  9   wheel_base         206 non-null    float64
#  10  length             208 non-null    float64
#  11  width              208 non-null    float64
#  12  height             208 non-null    float64
#  13  curb_weight        208 non-null    int64
#  14  engine_type        207 non-null    object
#  15  num_of_cylinders   208 non-null    object
# ...

# %%
df.describe()
# Out:
#        Unnamed: 0.1  Unnamed: 0  wheel_base      length       width  \
# count    208.000000  208.000000  206.000000  208.000000  208.000000
# mean     103.456731  104.456731   98.919903  174.262019   65.950962
# std       60.115573   60.115573    6.121266   12.373790    2.159419
# min        0.000000    1.000000   86.600000  141.100000   60.300000
# 25%       51.750000   52.750000   94.500000  166.675000   64.100000
# 50%      103.500000  104.500000   97.000000  173.200000   65.500000
# 75%      155.250000  156.250000  102.400000  183.775000   66.900000
# max      204.000000  205.000000  120.900000  208.100000   72.300000
#
#            height  curb_weight  engine_size  compression_ratio    city_mpg  \
# count  208.000000   208.000000   206.000000         208.000000  208.000000
# mean    53.750481  2563.375000   127.543689          10.194808   25.158654
# std      2.435010   521.034018    41.599197           4.044135    6.528187
# ...

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ### Duplicates values

# %%
df.duplicated().sum()
# Out:
# 3

# %%
df.drop_duplicates(keep = "first",inplace = True)

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Structural errors

# %%
df.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'make', 'fuel_type', 'aspiration',
#        'num_of_doors', 'body_style', 'drive_wheels', 'engine_location',
#        'wheel_base', 'length', 'width', 'height', 'curb_weight', 'engine_type',
#        'num_of_cylinders', 'engine_size', 'fuel_system', 'compression_ratio',
#        'horsepower', 'peak_rpm', 'city_mpg', 'highway_mpg', 'price'],
#       dtype='object')

# %%
df.drop(['Unnamed: 0.1', 'Unnamed: 0'],axis = 1,inplace =True)

# %%
df.columns
# Out:
# Index(['make', 'fuel_type', 'aspiration', 'num_of_doors', 'body_style',
#        'drive_wheels', 'engine_location', 'wheel_base', 'length', 'width',
#        'height', 'curb_weight', 'engine_type', 'num_of_cylinders',
#        'engine_size', 'fuel_system', 'compression_ratio', 'horsepower',
#        'peak_rpm', 'city_mpg', 'highway_mpg', 'price'],
#       dtype='object')

# %% [markdown]
# to find the structural errors
# if data type is categorical  --- unique method()'body_style'
# if data type is numerical   -----

# %%
df["make"].dtype
# Out:
# dtype('O')

# %%
df["make"].unique() # there is no structural error
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'mazda', 'mercedes-benz', 'mercury',
#        'mitsubishi', 'nissan', 'peugot', 'plymouth', 'porsche', 'renault',
#        'saab', 'subaru', 'toyota', 'volkswagen', 'volvo'], dtype=object)

# %%
df['fuel_type'].dtype
# Out:
# dtype('O')

# %%
df['fuel_type'].unique()
# Out:
# array(['gas', 'diesel'], dtype=object)

# %%
df['aspiration'].dtype
# Out:
# dtype('O')

# %%
df['aspiration'].unique()
# Out:
# array(['std', 'turbo'], dtype=object)

# %%
df['num_of_doors'].unique()
# Out:
# array(['two', 'four', '?'], dtype=object)

# %%
def door(n):
    if n=='two':
        return 2
    elif n== 'four':
        return 4
    else:
        return np.nan

# %%
df['num_of_doors'] = df['num_of_doors'].apply(door)

# %%
df['num_of_doors'].unique()
# Out:
# array([ 2.,  4., nan])

# %%
df['body_style'].dtype
# Out:
# dtype('O')

# %%
df['body_style'].unique()
# Out:
# array(['convertible', 'hatchback', 'sedan', 'wagon', 'hardtop'],
#       dtype=object)

# %%
df['drive_wheels'].dtype
# Out:
# dtype('O')

# %%
df['drive_wheels'].unique()
# Out:
# array(['rwd', 'fwd', '4wd'], dtype=object)

# %%
df['engine_location'].dtype
# Out:
# dtype('O')

# %%
df['engine_location'].unique()
# Out:
# array(['front', 'rear'], dtype=object)

# %%
df['wheel_base'].dtype
# Out:
# dtype('float64')

# %%
df['wheel_base'].unique()
# Out:
# array([ 88.6,  94.5,  99.8,  99.4, 105.8,  99.5, 101.2,   nan, 103.5,
#        110. ,  88.4,  93.7, 103.3,  95.9,  86.6,  96.5,  94.3,  96. ,
#        113. , 102. ,  93.1,  95.3,  98.8, 104.9, 106.7, 115.6,  96.6,
#        120.9, 112. , 102.7,  93. ,  96.3,  95.1,  97.2, 100.4,  91.3,
#         99.2, 107.9, 114.2, 108. ,  89.5,  98.4,  96.1,  99.1,  93.3,
#         97. ,  96.9,  95.7, 102.4, 102.9, 104.5,  97.3, 104.3, 109.1])

# %%
df['length'].dtype
# Out:
# dtype('float64')

# %%
df['length'].unique()
# Out:
# array([168.8, 171.2, 176.6, 177.3, 192.7, 178.2, 176.8, 189. , 193.8,
#        197. , 141.1, 155.9, 158.8, 157.3, 174.6, 173.2, 144.6, 150. ,
#        163.4, 157.1, 167.5, 175.4, 169.1, 170.7, 172.6, 199.6, 191.7,
#        159.1, 166.8, 169. , 177.8, 175. , 190.9, 187.5, 202.6, 180.3,
#        208.1, 199.2, 178.4, 173. , 172.4, 165.3, 170.2, 165.6, 162.4,
#        173.4, 181.7, 184.6, 178.5, 186.7, 198.9, 167.3, 168.9, 175.7,
#        181.5, 186.6, 156.9, 157.9, 172. , 173.5, 173.6, 158.7, 169.7,
#        166.3, 168.7, 176.2, 175.6, 183.5, 187.8, 171.7, 159.3, 165.7,
#        180.2, 183.1, 188.8])

# %%
df.columns
# Out:
# Index(['make', 'fuel_type', 'aspiration', 'num_of_doors', 'body_style',
#        'drive_wheels', 'engine_location', 'wheel_base', 'length', 'width',
#        'height', 'curb_weight', 'engine_type', 'num_of_cylinders',
#        'engine_size', 'fuel_system', 'compression_ratio', 'horsepower',
#        'peak_rpm', 'city_mpg', 'highway_mpg', 'price'],
#       dtype='object')

# %%
df['width'].dtype
# Out:
# dtype('float64')

# %%
df['width'].unique()
# Out:
# array([64.1, 65.5, 66.2, 66.4, 66.3, 71.4, 67.9, 64.8, 66.9, 70.9, 60.3,
#        63.6, 63.8, 64.6, 63.9, 64. , 65.2, 62.5, 66. , 61.8, 69.6, 70.6,
#        64.2, 65.7, 66.5, 66.1, 70.3, 71.7, 70.5, 72. , 68. , 64.4, 65.4,
#        68.4, 68.3, 65. , 72.3, 66.6, 63.4, 65.6, 67.7, 67.2, 68.9, 68.8])

# %%
df['height'].dtype
# Out:
# dtype('float64')

# %%
df['height'].unique()
# Out:
# array([48.8, 52.4, 54.3, 53.1, 55.7, 55.9, 52. , 53.7, 56.3, 53.2, 50.8,
#        50.6, 59.8, 50.2, 52.6, 54.5, 58.3, 53.3, 54.1, 51. , 53.5, 51.4,
#        52.8, 47.8, 49.6, 55.5, 54.4, 56.5, 58.7, 54.9, 56.7, 55.4, 54.8,
#        49.4, 51.6, 54.7, 55.1, 56.1, 49.7, 56. , 50.5, 55.2, 52.5, 53. ,
#        59.1, 53.9, 55.6, 56.2, 57.5])

# %%
df['curb_weight'].dtype
# Out:
# dtype('int64')

# %%
df['curb_weight'].unique()
# Out:
# array([2548, 2823, 2337, 2824, 2507, 2844, 2954, 3086, 3053, 2395, 2710,
#        2765, 3055, 3230, 3380, 3505, 1488, 1874, 1909, 1876, 2128, 1967,
#        1989, 2191, 2535, 2811, 1713, 1819, 1837, 1940, 1956, 2010, 2024,
#        2236, 2289, 2304, 2372, 2465, 2293, 2734, 4066, 3950, 1890, 1900,
#        1905, 1945, 1950, 2380, 2385, 2500, 2410, 2443, 2425, 2670, 2700,
#        3515, 3750, 3495, 3770, 3740, 3685, 3900, 3715, 2910, 1918, 1944,
#        2004, 2145, 2370, 2328, 2833, 2921, 2926, 2365, 2405, 2403, 1889,
#        2017, 1938, 1951, 2028, 1971, 2037, 2008, 2324, 2302, 3095, 3296,
#        3060, 3071, 3139, 3020, 3197, 3430, 3075, 3252, 3285, 3485, 3130,
#        2818, 2778, 2756, 2800, 3366, 2579, 2460, 2658, 2695, 2707, 2758,
#        2808, 2847, 2050, 2120, 2240, 2190, 2340, 2510, 2290, 2455, 2420,
#        2650, 1985, 2040, 2015, 2280, 3110, 2081, 2109, 2275, 2094, 2122,
#        2140, 2169, 2204, 2265, 2300, 2540, 2536, 2551, 2679, 2714, 2975,
# ...

# %%
df['engine_type'].dtype
# Out:
# dtype('O')

# %%
df['engine_type'].unique()
# Out:
# array(['dohc', 'ohcv', 'ohc', 'l', 'rotor', nan, 'ohcf', 'dohcv'],
#       dtype=object)

# %%
df['num_of_cylinders'].dtype
# Out:
# dtype('O')

# %%
df['num_of_cylinders'].unique()
# Out:
# array(['four', 'six', 'five', 'three', 'twelve', 'two', 'eight'],
#       dtype=object)

# %%
def cyl(n):
    if n=="three":
        return 3
    elif n=="four":
        return 4
    elif n== "two":
        return 2
    elif n=="five":
        return 5
    elif n=="six":
        return 6
    elif n=="eight":
        return 8
    else:
        return 12

# %%
df['num_of_cylinders'] = df['num_of_cylinders'].apply(cyl)

# %%
df['num_of_cylinders'].dtype,df['num_of_cylinders'].unique()
# Out:
# (dtype('int64'), array([ 4,  6,  5,  3, 12,  2,  8], dtype=int64))

# %%
df['num_of_cylinders']
# Out:
# 0      4
# 1      4
# 2      6
# 3      4
# 4      5
#       ..
# 200    4
# 201    4
# 202    6
# 203    6
# 204    4
# Name: num_of_cylinders, Length: 205, dtype: int64

# %%
df['engine_size'].dtype
# Out:
# dtype('float64')

# %%
df['engine_size'].unique()
# Out:
# array([130., 152., 109., 136., 131., 108., 164., 209.,  61.,  90.,  98.,
#        122., 156.,  92.,  79., 110.,  nan, 111., 119., 258., 326.,  91.,
#         70.,  80., 140., 134., 183., 234., 308., 304.,  97., 103., 120.,
#        181., 151., 194., 203., 132., 121., 146., 171., 161., 141., 173.,
#        145.])

# %%
df.columns
# Out:
# Index(['make', 'fuel_type', 'aspiration', 'num_of_doors', 'body_style',
#        'drive_wheels', 'engine_location', 'wheel_base', 'length', 'width',
#        'height', 'curb_weight', 'engine_type', 'num_of_cylinders',
#        'engine_size', 'fuel_system', 'compression_ratio', 'horsepower',
#        'peak_rpm', 'city_mpg', 'highway_mpg', 'price'],
#       dtype='object')

# %%
df['fuel_system'].dtype
# Out:
# dtype('O')

# %%
df['fuel_system'].unique()
# Out:
# array(['mpfi', '2bbl', 'mfi', '1bbl', 'spfi', '4bbl', 'idi', 'spdi'],
#       dtype=object)

# %%
df['compression_ratio'].dtype
# Out:
# dtype('float64')

# %%
df['compression_ratio'].unique()
# Out:
# array([ 9.  , 10.  ,  8.  ,  8.5 ,  8.3 ,  7.  ,  8.8 ,  9.5 ,  9.6 ,
#         9.41,  9.4 ,  7.6 ,  9.2 , 10.1 ,  9.1 ,  8.1 , 11.5 ,  8.6 ,
#        22.7 , 22.  , 21.5 ,  7.5 , 21.9 ,  7.8 ,  8.4 , 21.  ,  8.7 ,
#         9.31,  9.3 ,  7.7 , 22.5 , 23.  ])

# %%
df['horsepower'].dtype
# Out:
# dtype('O')

# %%
df['horsepower'].str.isnumeric().value_counts()
# Out:
# True     203
# False      2
# Name: horsepower, dtype: int64

# %%
df[~df['horsepower'].str.isnumeric()]
# Out:
#         make fuel_type aspiration  num_of_doors body_style drive_wheels  \
# 130  renault       gas        std           4.0      wagon          fwd
# 131  renault       gas        std           2.0  hatchback          fwd
#
#     engine_location  wheel_base  length  width  ...  engine_type  \
# 130           front        96.1   181.5   66.5  ...          ohc
# 131           front        96.1   176.8   66.6  ...          ohc
#
#      num_of_cylinders engine_size  fuel_system  compression_ratio horsepower  \
# 130                 4       132.0         mpfi                8.7          ?
# 131                 4       132.0         mpfi                8.7          ?
#
#      peak_rpm city_mpg highway_mpg  price
# 130         ?       23          31   9295
# 131         ?       23          31   9895
#
# [2 rows x 22 columns]

# %%
df['horsepower'] = df['horsepower'].replace("?",np.nan)

# %%
df['horsepower'].unique()
# Out:
# array(['111', '154', '102', '115', '110', '140', '160', '101', '121',
#        '182', '48', '70', '68', '88', '145', '58', '76', '60', '86',
#        '100', '78', '90', '176', '262', '135', '84', '64', '120', '72',
#        '123', '155', '184', '175', '116', '69', '55', '97', '152', '200',
#        '95', '142', '143', '207', '288', nan, '73', '82', '94', '62',
#        '56', '112', '92', '161', '156', '52', '85', '114', '162', '134',
#        '106'], dtype=object)

# %%
df['peak_rpm'].dtype
# Out:
# dtype('O')

# %%
df['peak_rpm'].unique()
# Out:
# array(['5000', '5500', '5800', '4250', '5400', '5100', '4800', '6000',
#        '4750', '4650', '4200', '4350', '4500', '5200', '4150', '5600',
#        '5900', '5750', '?', '5250', '4900', '4400', '6600', '5300'],
#       dtype=object)

# %%
df['peak_rpm'] = df['peak_rpm'].replace("?",np.nan)

# %%
df['peak_rpm'].unique()
# Out:
# array(['5000', '5500', '5800', '4250', '5400', '5100', '4800', '6000',
#        '4750', '4650', '4200', '4350', '4500', '5200', '4150', '5600',
#        '5900', '5750', nan, '5250', '4900', '4400', '6600', '5300'],
#       dtype=object)

# %%
df['city_mpg'].dtype
# Out:
# dtype('int64')

# %%
df['city_mpg'].unique()
# Out:
# array([21, 19, 24, 18, 17, 16, 23, 20, 15, 47, 38, 37, 31, 49, 30, 27, 25,
#        13, 26, 36, 22, 14, 45, 28, 32, 35, 34, 29, 33], dtype=int64)

# %%
df['highway_mpg'].dtype
# Out:
# dtype('int64')

# %%
df['highway_mpg'].unique()
# Out:
# array([27, 26, 30, 22, 25, 20, 29, 28, 53, 43, 41, 38, 24, 54, 42, 34, 33,
#        31, 19, 17, 23, 32, 39, 18, 16, 37, 50, 36, 47, 46], dtype=int64)

# %%
df['price'].dtype
# Out:
# dtype('O')

# %%
df['price'].unique()
# Out:
# array(['13495', '16500', '13950', '17450', '15250', '17710', '18920',
#        '23875', '?', '16430', '16925', '20970', '21105', '24565', '30760',
#        '41315', '36880', '5151', '6295', '6575', '5572', '6377', '7957',
#        '6229', '6692', '7609', '8558', '8921', '12964', '6479', '6855',
#        '5399', '6529', '7129', '7295', '7895', '9095', '8845', '10295',
#        '12945', '10345', '6785', '11048', nan, '35550', '36000', '5195',
#        '6095', '6795', '6695', '7395', '10945', '11845', '13645', '15645',
#        '8495', '10595', '10245', '10795', '11245', '18280', '18344',
#        '25552', '28248', '28176', '31600', '34184', '35056', '40960',
#        '45400', '16503', '5389', '6189', '6669', '7689', '9959', '8499',
#        '12629', '14869', '14489', '6989', '8189', '9279', '5499', '7099',
#        '6649', '6849', '7349', '7299', '7799', '7499', '7999', '8249',
#        '8949', '9549', '13499', '14399', '17199', '19699', '18399',
# ...

# %%
df['price'] = df['price'].replace("?",np.nan)

# %%
df['price']
# Out:
# 0      13495
# 1      16500
# 2      16500
# 3      13950
# 4      17450
#        ...
# 200    16845
# 201    19045
# 202    21485
# 203      NaN
# 204    22625
# Name: price, Length: 205, dtype: object

# %%
df.isna().sum()
# Out:
# make                 0
# fuel_type            0
# aspiration           0
# num_of_doors         2
# body_style           0
# drive_wheels         0
# engine_location      0
# wheel_base           2
# length               0
# width                0
# height               0
# curb_weight          0
# engine_type          1
# num_of_cylinders     0
# engine_size          2
# fuel_system          0
# compression_ratio    0
# horsepower           2
# peak_rpm             2
# city_mpg             0
# highway_mpg          0
# price                7
# dtype: int64

# %%
df["num_of_doors"].isna().sum()
# Out:
# 2

# %%
df["wheel_base"].fillna(df["wheel_base"].mean(),inplace  = True)
df["engine_type"].fillna(df["engine_type"].mode()[0],inplace = True)
df['engine_size'].fillna(df["engine_size"].median(),inplace = True)
df["horsepower"].fillna(df["horsepower"].median(),inplace =True)
df["peak_rpm"].fillna(df["peak_rpm"].median(),inplace = True)
df["price"].fillna(df["price"].median(),inplace = True)
df["num_of_doors"].fillna(df["num_of_doors"].median(),inplace = True)

# %%
df["num_of_doors"].isna().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# make                 0
# fuel_type            0
# aspiration           0
# num_of_doors         0
# body_style           0
# drive_wheels         0
# engine_location      0
# wheel_base           0
# length               0
# width                0
# height               0
# curb_weight          0
# engine_type          0
# num_of_cylinders     0
# engine_size          0
# fuel_system          0
# compression_ratio    0
# horsepower           0
# peak_rpm             0
# city_mpg             0
# highway_mpg          0
# price                0
# dtype: int64

# %% [markdown]
# ## type conversion

# %%
df["price"] = df["price"].astype("int64")

# %%
df["peak_rpm"] = df["peak_rpm"].astype("int64")

# %%
df["horsepower"] = df["horsepower"].astype("int64")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 205 entries, 0 to 204
# Data columns (total 22 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   make               205 non-null    object
#  1   fuel_type          205 non-null    object
#  2   aspiration         205 non-null    object
#  3   num_of_doors       205 non-null    float64
#  4   body_style         205 non-null    object
#  5   drive_wheels       205 non-null    object
#  6   engine_location    205 non-null    object
#  7   wheel_base         205 non-null    float64
#  8   length             205 non-null    float64
#  9   width              205 non-null    float64
#  10  height             205 non-null    float64
#  11  curb_weight        205 non-null    int64
#  12  engine_type        205 non-null    object
#  13  num_of_cylinders   205 non-null    int64
#  14  engine_size        205 non-null    float64
#  15  fuel_system        205 non-null    object
# ...

# %% [markdown]
# # univariate analysis

# %% [markdown]
# ## Numerical

# %% [markdown]
# ## Histogram

# %%
plt.style.use('ggplot')

# %%
df.dtypes
# Out:
# make                  object
# fuel_type             object
# aspiration            object
# num_of_doors         float64
# body_style            object
# drive_wheels          object
# engine_location       object
# wheel_base           float64
# length               float64
# width                float64
# height               float64
# curb_weight            int64
# engine_type           object
# num_of_cylinders       int64
# engine_size          float64
# fuel_system           object
# compression_ratio    float64
# horsepower             int64
# peak_rpm               int64
# city_mpg               int64
# highway_mpg            int64
# price                  int64
# dtype: object

# %%
df['num_of_cylinders'].plot(kind='hist',                  # histogram for cylinders
                            xlabel='No of Cylinders',
                           title='Histogram of No of cylinders',
                           color='purple',
                           figsize=(4,3),
                           grid = True)
# Out:
# <Axes: title={'center': 'Histogram of No of cylinders'}, ylabel='Frequency'>

# %% [markdown]
# Conclusion for " Histogram of No of Cylinders in cars"
# There is highest number of cars which is having 4 cylinder.
# There is approx 160 cars having 4 cylinders
# There is lowest number cars which is having 3 and 12 cylinder.
# There us approx only 2 cars having 3 and 12 cylinder

# %%
df['num_of_cylinders'].plot(kind = "box",figsize = (5,3)) # box plot for cylinders
# Out:
# <Axes: >

# %%
df["num_of_cylinders"].plot(kind  = "density", # box plot for cylinders
                 color = "#b78cbd",
                  figsize = (6,3))
# Out:
# <Axes: ylabel='Density'>

# %%
df['horsepower'].plot(kind='hist',
                      xlabel='horsepower', # histogram for horse power
                     title='Histogram of horse power',
                     color='purple',
                     figsize=(4,3))
# Out:
# <Axes: title={'center': 'Histogram of horse power'}, ylabel='Frequency'>

# %%
df["horsepower"].plot(kind  = "density", # density plot for horse power
                 color = "#b78cbd",
                  figsize = (6,3))
# Out:
# <Axes: ylabel='Density'>

# %%
df['horsepower'].plot(kind = "box",figsize = (5,3)) #  box plot for horse power
# Out:
# <Axes: >

# %%
df["price"].plot(kind = "hist",
                  color = "#42f578",
                   figsize = (10,4))
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['price'].plot(kind = "box",figsize = (5,3))
# Out:
# <Axes: >

# %%
df["price"].plot(kind  = "density", 
                 color = "#b78cbd",
                  figsize = (6,3))
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# # conclusions
# ##### the minimum price of purchasing the car is - 5000
# ##### the maximum price of purchasing the car is - 45000
# ##### there are 80 cars ranges from 5000 to 1000

# %%
df["length"].plot(kind = "hist",
                  color = "#421647",
                 figsize = (6,3) )
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# # Density plot

# %%
df["length"].plot(kind  = "density",
                 color = "#b78cbd",
                  figsize = (6,3))
# Out:
# <Axes: ylabel='Density'>

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
df.columns
# Out:
# Index(['make', 'fuel_type', 'aspiration', 'num_of_doors', 'body_style',
#        'drive_wheels', 'engine_location', 'wheel_base', 'length', 'width',
#        'height', 'curb_weight', 'engine_type', 'num_of_cylinders',
#        'engine_size', 'fuel_system', 'compression_ratio', 'horsepower',
#        'peak_rpm', 'city_mpg', 'highway_mpg', 'price'],
#       dtype='object')

# %% [markdown]
# # Box plot

# %%
df["price"].plot(kind = "box",figsize = (5,3))
# Out:
# <Axes: >

# %%
df["highway_mpg"].plot(kind = "box",figsize = (6,3))
# Out:
# <Axes: >

# %%
df['length'].plot(kind = "box",
                  color = "purple",
                  figsize = (5,4)
                 )
# Out:
# <Axes: >

# %% [markdown]
# # Categorical

# %% [markdown]
# # Bar plot

# %%
df["make"].value_counts().plot(kind = "bar",
                           color = ["purple","pink"], # make is a object dtype thats why we have used barplot
                           
                         )
# Out:
# <Axes: >

# %%
df['body_style'] .value_counts().plot(kind ="bar",
                                      color = ["#522a27","#225e32"],
                                       position = 0,
                                        grid = True)
# Out:
# <Axes: >

# %%
sns.countplot(data = df,x= "body_style",width = 0.5,)
# Out:
# <Axes: xlabel='body_style', ylabel='count'>

# %%
df['fuel_type'].value_counts().plot(kind = "bar",
                                    color = ["green","orange"],
                                    position = 0,
                                    grid = True
                                   )
# Out:
# <Axes: >

# %%
plt.style.use('classic')
plt.style.use('fivethirtyeight')

# %%
df['fuel_system'].value_counts().plot(kind = "bar",
                                      color = 'pink')
# Out:
# <Axes: >

# %%
sns.countplot(data = df,x= "make",width = 0.5,)
# Out:
# <Axes: xlabel='make', ylabel='count'>

# %%
df.head()
# Out:
#           make fuel_type aspiration  num_of_doors   body_style drive_wheels  \
# 0  alfa-romero       gas        std           2.0  convertible          rwd
# 1  alfa-romero       gas        std           2.0  convertible          rwd
# 2  alfa-romero       gas        std           2.0    hatchback          rwd
# 3         audi       gas        std           4.0        sedan          fwd
# 4         audi       gas        std           4.0        sedan          4wd
#
#   engine_location  wheel_base  length  width  ...  engine_type  \
# 0           front        88.6   168.8   64.1  ...         dohc
# 1           front        88.6   168.8   64.1  ...         dohc
# 2           front        94.5   171.2   65.5  ...         ohcv
# 3           front        99.8   176.6   66.2  ...          ohc
# 4           front        99.4   176.6   66.4  ...          ohc
#
#    num_of_cylinders engine_size  fuel_system  compression_ratio horsepower  \
# ...

# %%
df["fuel_type"].value_counts().plot(kind="pie",autopct = "%1.1f",legend = True,ylabel="Percentage")
# Out:
# <Axes: ylabel='Percentage'>

# %% [markdown]
# ### Insights from above Pie Chart
#
# 89.9% of gas cars
# 10.1% of diesel cars

# %%
(df["body_style"].value_counts()/len(df["body_style"])*100).plot(kind = "pie",
                                                                 ylabel = "percentage",
                                                                 
                                                                  autopct = '%1.1f',
                                                                   legend = True)
# Out:
# <Axes: ylabel='percentage'>

# %%
(df["drive_wheels"].value_counts()/len(df["drive_wheels"])*100).plot(kind = "pie",
                                                                 ylabel = "percentage",
                                                                 
                                                                  autopct = '%1.1f',
                                                                   legend = True)
# Out:
# <Axes: ylabel='percentage'>

# %% [markdown]
# # count plot

# %%
sns.countplot(data = df,x= "drive_wheels",width = 0.2)
# Out:
# <Axes: xlabel='drive_wheels', ylabel='count'>

# %%
sns.countplot(data = df,x = "engine_location",width = 0.3)
# Out:
# <Axes: xlabel='engine_location', ylabel='count'>

# %%
df["engine_location"].value_counts().plot(kind = "bar",figsize = (4,3))
# Out:
# <Axes: >

# %% [markdown]
# ### conclusion for engine location

# %% [markdown]
# # pie chart

# %%
df.dtypes
# Out:
# make                  object
# fuel_type             object
# aspiration            object
# num_of_doors         float64
# body_style            object
# drive_wheels          object
# engine_location       object
# wheel_base           float64
# length               float64
# width                float64
# height               float64
# curb_weight            int64
# engine_type           object
# num_of_cylinders       int64
# engine_size          float64
# fuel_system           object
# compression_ratio    float64
# horsepower             int64
# peak_rpm               int64
# city_mpg               int64
# highway_mpg            int64
# price                  int64
# dtype: object

# %%
(df["fuel_system"].value_counts()/len(df["fuel_system"])*100).plot(kind = "pie",
                                                                 ylabel = "percentage",
                                                                 
                                                                  autopct = '%1.1f',
                                                                   legend = True)
# Out:
# <Axes: ylabel='percentage'>

# %% [markdown]
# # Conclusion for Pie Chart of fuel system in cars
#
# Highest percentage of cars having mpfi(MULTI POINT FUEL INJECTION) fuel system
# Lowest percentage of cars having spfi(SINGLE POINT FUEL INJECTION) fuel system
# There is 45.9 percent of cars having mpfi(MULTI POINT FUEL INJECTION) fuel system
# There is only 0.5 percent of cars having spfi(SINGLE POINT FUEL INJECTION) fuel system

# %%
(df["fuel_type"].value_counts()/len(df["fuel_type"])*100).plot(kind = "pie",
                                                                 ylabel = "percentage",
                                                                 
                                                                  autopct = '%1.1f',
                                                                   legend = True)
# Out:
# <Axes: ylabel='percentage'>

# %%
(df["engine_location"].value_counts()/len(df["engine_location"])*100).plot(kind = "pie",
                                                                 ylabel = "percentage",
                                                                 
                                                                  autopct = '%1.1f',
                                                                   legend = True)
# Out:
# <Axes: ylabel='percentage'>

# %% [markdown]
# # Bi variate analysis

# %%
df.dtypes
# Out:
# make                  object
# fuel_type             object
# aspiration            object
# num_of_doors         float64
# body_style            object
# drive_wheels          object
# engine_location       object
# wheel_base           float64
# length               float64
# width                float64
# height               float64
# curb_weight            int64
# engine_type           object
# num_of_cylinders       int64
# engine_size          float64
# fuel_system           object
# compression_ratio    float64
# horsepower             int64
# peak_rpm               int64
# city_mpg               int64
# highway_mpg            int64
# price                  int64
# dtype: object

# %% [markdown]
# # categorical and categorical

# %%
pd.crosstab(df['fuel_system'],df['body_style'])
# Out:
# body_style   convertible  hardtop  hatchback  sedan  wagon
# fuel_system
# 1bbl                   0        0          7      3      1
# 2bbl                   0        1         28     28      9
# 4bbl                   0        0          3      0      0
# idi                    0        1          1     15      3
# mfi                    0        0          1      0      0
# mpfi                   6        6         22     48     12
# spdi                   0        0          7      2      0
# spfi                   0        0          1      0      0

# %% [markdown]
# # crosstab

# %%
pd.crosstab(df["engine_type"],df["aspiration"])
# Out:
# aspiration   std  turbo
# engine_type
# dohc          10      2
# dohcv          1      0
# l              6      6
# ohc          122     26
# ohcf          13      2
# ohcv          12      1
# rotor          4      0

# %% [markdown]
# # count plot

# %%
sns.countplot(data =df,x = "body_style",hue= "fuel_type") # here u can not apply direct on data frame  from the seaborn
# u can go for the count plot
# Out:
# <Axes: xlabel='body_style', ylabel='count'>

# %%
sns.countplot(data=df,x='make',hue='fuel_type',width=0.6)
# Out:
# <Axes: xlabel='make', ylabel='count'>

# %%
sns.countplot(data=df,x='aspiration',hue='body_style')
# Out:
# <Axes: xlabel='aspiration', ylabel='count'>

# %%
sns.countplot(data=df,x='engine_location',hue='drive_wheels',width=0.5)
# Out:
# <Axes: xlabel='engine_location', ylabel='count'>

# %%
sns.countplot(data=df,x='fuel_system',hue='engine_type',width=1)
# Out:
# <Axes: xlabel='fuel_system', ylabel='count'>

# %%
ax=plt.subplot() # matplotlib
ax.bar(df['body_style'],df['num_of_doors'])
ax.bar(df['body_style'],df['num_of_cylinders'],bottom=df['num_of_doors'])
# Out:
# <BarContainer object of 205 artists>

# %% [markdown]
# # stacked bar

# %%
import matplotlib.pyplot as plt # we can use thise for categorical vs numerical also

#Dtat
groups = ["G1","G2","G3","G4","G5"]
male =[12,19,14,27,16]
female = [21,30,15,17,20]

fig, ax = plt.subplots()
#stackedbar cahrt
ax.bar(groups,male)
ax.bar(groups,female,bottom = male)
#plt.show
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# # categorical and numerical

# %% [markdown]
#  Group by , pivot, line chart

# %% [markdown]
# # group by

# %%
df.groupby(by = "engine_type")["price"].mean()
# Out:
# engine_type
# dohc     16280.666667
# dohcv    10221.000000
# l        14071.000000
# ohc      11457.304054
# ohcf     13738.600000
# ohcv     25098.384615
# rotor    13020.000000
# Name: price, dtype: float64

# %% [markdown]
# # line chart

# %%
df["price"].plot(kind="line")
# Out:
# <Axes: >

# %%
df["city_mpg"].plot(kind = "line",color = "purple")
# Out:
# <Axes: >

# %% [markdown]
# # Numerical and Numerical

# %% [markdown]
# ## scatter plot

# %%
df.corr(numeric_only = True)
# Out:
#                    num_of_doors  wheel_base    length     width    height  \
# num_of_doors           1.000000    0.434134  0.385675  0.197735  0.540286
# wheel_base             0.434134    1.000000  0.870403  0.793806  0.585280
# length                 0.385675    0.870403  1.000000  0.841118  0.491029
# width                  0.197735    0.793806  0.841118  1.000000  0.279210
# height                 0.540286    0.585280  0.491029  0.279210  1.000000
# curb_weight            0.190720    0.773262  0.877728  0.867032  0.295572
# num_of_cylinders      -0.019503    0.339476  0.430672  0.545007 -0.013995
# engine_size            0.017968    0.565307  0.682920  0.733872  0.067997
# compression_ratio      0.171797    0.250218  0.158414  0.181129  0.261214
# horsepower            -0.127846    0.350007  0.553337  0.641337 -0.109286
# peak_rpm              -0.240473   -0.361671 -0.286362 -0.219374 -0.321113
# city_mpg              -0.014271   -0.467094 -0.670909 -0.642704 -0.048640
# ...

# %%
df.plot('engine_size','city_mpg',kind='scatter',
                                    legend = True,
                                    figsize=(10,4),
                                    grid=True,
                                    title='Scatter Plot between engine size and curb weight of vehicle')
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\core.py:1259: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <Axes: title={'center': 'Scatter Plot between engine size and curb weight of vehicle'}, xlabel='engine_size', ylabel='city_mpg'>

# %%
# finds the relatioship between two numerical columns

# %%
df.plot("wheel_base","length",kind ="scatter")
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\core.py:1259: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <Axes: xlabel='wheel_base', ylabel='length'>

# %%
df.plot("length","city_mpg" , kind = "scatter")
# Out:
# <Axes: xlabel='length', ylabel='city_mpg'>

# %%
df.plot('num_of_doors',"price",kind = "scatter")
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\core.py:1259: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <Axes: xlabel='num_of_doors', ylabel='price'>

# %%
sns.heatmap(df.corr(numeric_only = True),annot = True)
# Out:
# <Axes: >

# %%
sns.pairplot(df)

# %% [markdown]
# # seaborn

# %%
sns.boxplot(df["city_mpg"],orient ="h")
# Out:
# <Axes: >

# %%
sns.histplot(df["city_mpg"])
# Out:
# <Axes: xlabel='city_mpg', ylabel='Count'>

# %%
sns.distplot(df["city_mpg"])
# Out:
# C:\Users\heena\AppData\Local\Temp\ipykernel_6336\3862671593.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["city_mpg"])
# <Axes: xlabel='city_mpg', ylabel='Density'>

# %%
sns.catplot(df["city_mpg"])

# %%
sns.kdeplot(df["price"])
# Out:
# <Axes: xlabel='price', ylabel='Density'>

# %%
sns.jointplot(df["price"])

# %% [markdown]
# # Data Manipulation

# %%
#What is the maximum price of audi car?
df[df['make'] == 'audi']['price'].max()
# Out:
# 23875

# %%
#What is minimum number of cylinders in hatchback?
df[df["body_style"] == 'hatchback']["num_of_cylinders"].min()
# Out:
# 2

# %%
#Which fuel system is used most for Gas fuel type?
df[df["fuel_type"] == 'gas']["fuel_system"].mode()[0]
# Out:
# 'mpfi'
