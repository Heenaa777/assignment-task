# %% [markdown]
# # importing libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings as wr
wr.filterwarnings('ignore')

# %% [markdown]
# # Importing dataset

# %%
df = pd.read_excel(r"C:\Users\heena\Downloads\Sample_-_Superstore.xls")

# %%
df.head() # first five rows of data set
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df.info() # information about data set
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   datetime64[ns]
#  3   Ship Date      9994 non-null   datetime64[ns]
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
df.describe() # statastical measurements about data set
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %% [markdown]
# # Data cleaning

# %% [markdown]
# # finding duplicate values

# %%
df.duplicated().sum()# there are no duplicate values
# Out:
# 0

# %% [markdown]
# # finding structural errors

# %%
df.drop(["Row ID"],axis = 1,inplace =True) # droping the row

# %%
df.columns
# Out:
# Index(['Order ID', 'Order Date', 'Ship Date', 'Ship Mode', 'Customer ID',
#        'Customer Name', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Product ID', 'Category', 'Sub-Category', 'Product Name',
#        'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df['Order ID'].unique() # there are no structural errors
# Out:
# array(['CA-2016-152156', 'CA-2016-138688', 'US-2015-108966', ...,
#        'CA-2014-110422', 'CA-2017-121258', 'CA-2017-119914'], dtype=object)

# %%
df['Order Date'].unique() # there are no structural errors
# Out:
# array(['2016-11-08T00:00:00.000000000', '2016-06-12T00:00:00.000000000',
#        '2015-10-11T00:00:00.000000000', ...,
#        '2016-06-03T00:00:00.000000000', '2015-04-12T00:00:00.000000000',
#        '2014-01-21T00:00:00.000000000'], dtype='datetime64[ns]')

# %%
df['Ship Date'].unique()
# Out:
# array(['2016-11-11T00:00:00.000000000', '2016-06-16T00:00:00.000000000',
#        '2015-10-18T00:00:00.000000000', ...,
#        '2015-05-23T00:00:00.000000000', '2014-01-23T00:00:00.000000000',
#        '2017-03-03T00:00:00.000000000'], dtype='datetime64[ns]')

# %%
df['Ship Mode'].unique()
# Out:
# array(['Second Class', 'Standard Class', 'First Class', 'Same Day'],
#       dtype=object)

# %%
df['Customer ID'].unique()
# Out:
# array(['CG-12520', 'DV-13045', 'SO-20335', 'BH-11710', 'AA-10480',
#        'IM-15070', 'HP-14815', 'PK-19075', 'AG-10270', 'ZD-21925',
#        'KB-16585', 'SF-20065', 'EB-13870', 'EH-13945', 'TB-21520',
#        'MA-17560', 'GH-14485', 'SN-20710', 'LC-16930', 'RA-19885',
#        'ES-14080', 'ON-18715', 'PO-18865', 'LH-16900', 'DP-13000',
#        'JM-15265', 'TB-21055', 'KM-16720', 'PS-18970', 'BS-11590',
#        'KD-16270', 'HM-14980', 'JE-15745', 'KB-16600', 'SC-20770',
#        'DN-13690', 'JC-16105', 'CS-12400', 'PG-18895', 'GM-14455',
#        'JS-15685', 'KB-16315', 'RB-19705', 'PN-18775', 'KD-16345',
#        'ER-13855', 'RB-19465', 'GZ-14470', 'LC-16870', 'JM-15250',
#        'PA-19060', 'CV-12805', 'CL-12565', 'RC-19960', 'DK-13090',
#        'GG-14650', 'SC-20725', 'AD-10180', 'PF-19165', 'TS-21610',
#        'LS-16975', 'DW-13585', 'LC-16885', 'JD-15895', 'SH-19975',
#        'SG-20080', 'HA-14920', 'MG-17680', 'JE-16165', 'TW-21025',
# ...

# %%
df['Customer Name'].unique()
# Out:
# array(['Claire Gute', 'Darrin Van Huff', "Sean O'Donnell",
#        'Brosina Hoffman', 'Andrew Allen', 'Irene Maddox', 'Harold Pawlan',
#        'Pete Kriz', 'Alejandro Grove', 'Zuschuss Donatelli', 'Ken Black',
#        'Sandra Flanagan', 'Emily Burns', 'Eric Hoffmann',
#        'Tracy Blumstein', 'Matt Abelman', 'Gene Hale', 'Steve Nguyen',
#        'Linda Cazamias', 'Ruben Ausman', 'Erin Smith', 'Odella Nelson',
#        "Patrick O'Donnell", 'Lena Hernandez', 'Darren Powers',
#        'Janet Molinari', 'Ted Butterfield', 'Kunst Miller',
#        'Paul Stevenson', 'Brendan Sweed', 'Karen Daniels',
#        'Henry MacAllister', 'Joel Eaton', 'Ken Brennan',
#        'Stewart Carmichael', 'Duane Noonan', 'Julie Creighton',
#        'Christopher Schild', 'Paul Gonzalez', 'Gary Mitchum', 'Jim Sink',
#        'Karl Braun', 'Roger Barcio', 'Parhena Norris', 'Katherine Ducich',
#        'Elpida Rittenbach', 'Rick Bensley', 'Gary Zandusky',
# ...

# %%
df['Segment'].unique()
# Out:
# array(['Consumer', 'Corporate', 'Home Office'], dtype=object)

# %%
df['Country'].unique()
# Out:
# array(['United States'], dtype=object)

# %%
df['City'].unique()
# Out:
# array(['Henderson', 'Los Angeles', 'Fort Lauderdale', 'Concord',
#        'Seattle', 'Fort Worth', 'Madison', 'West Jordan', 'San Francisco',
#        'Fremont', 'Philadelphia', 'Orem', 'Houston', 'Richardson',
#        'Naperville', 'Melbourne', 'Eagan', 'Westland', 'Dover',
#        'New Albany', 'New York City', 'Troy', 'Chicago', 'Gilbert',
#        'Springfield', 'Jackson', 'Memphis', 'Decatur', 'Durham',
#        'Columbia', 'Rochester', 'Minneapolis', 'Portland', 'Saint Paul',
#        'Aurora', 'Charlotte', 'Orland Park', 'Urbandale', 'Columbus',
#        'Bristol', 'Wilmington', 'Bloomington', 'Phoenix', 'Roseville',
#        'Independence', 'Pasadena', 'Newark', 'Franklin', 'Scottsdale',
#        'San Jose', 'Edmond', 'Carlsbad', 'San Antonio', 'Monroe',
#        'Fairfield', 'Grand Prairie', 'Redlands', 'Hamilton', 'Westfield',
#        'Akron', 'Denver', 'Dallas', 'Whittier', 'Saginaw', 'Medina',
#        'Dublin', 'Detroit', 'Tampa', 'Santa Clara', 'Lakeville',
# ...

# %%
df['State'].unique()
# Out:
# array(['Kentucky', 'California', 'Florida', 'North Carolina',
#        'Washington', 'Texas', 'Wisconsin', 'Utah', 'Nebraska',
#        'Pennsylvania', 'Illinois', 'Minnesota', 'Michigan', 'Delaware',
#        'Indiana', 'New York', 'Arizona', 'Virginia', 'Tennessee',
#        'Alabama', 'South Carolina', 'Oregon', 'Colorado', 'Iowa', 'Ohio',
#        'Missouri', 'Oklahoma', 'New Mexico', 'Louisiana', 'Connecticut',
#        'New Jersey', 'Massachusetts', 'Georgia', 'Nevada', 'Rhode Island',
#        'Mississippi', 'Arkansas', 'Montana', 'New Hampshire', 'Maryland',
#        'District of Columbia', 'Kansas', 'Vermont', 'Maine',
#        'South Dakota', 'Idaho', 'North Dakota', 'Wyoming',
#        'West Virginia'], dtype=object)

# %%
df['Postal Code'].unique()
# Out:
# array([42420, 90036, 33311, 90032, 28027, 98103, 76106, 53711, 84084,
#        94109, 68025, 19140, 84057, 90049, 77095, 75080, 77041, 60540,
#        32935, 55122, 48185, 19901, 47150, 10024, 12180, 90004, 60610,
#        85234, 22153, 10009, 49201, 38109, 77070, 35601, 94122, 27707,
#        60623, 29203, 55901, 55407, 97206, 55106, 80013, 28205, 60462,
#        10035, 50322, 43229, 37620, 19805, 61701, 85023, 95661, 64055,
#        91104, 43055, 53132, 85254, 95123, 98105, 98115, 73034, 90045,
#        19134, 88220, 78207, 77036, 62521, 71203,  6824, 75051, 92374,
#        45011,  7090, 19120, 44312, 80219, 75220, 37064, 90604, 48601,
#        44256, 43017, 48227, 38401, 33614, 95051, 55044, 92037, 77506,
#        94513, 27514,  7960, 45231, 94110, 90301, 33319, 80906,  7109,
#        48180,  8701, 22204, 80004,  7601, 33710, 19143, 90805, 92345,
#        37130, 84041, 78745,  1852, 31907,  6040, 78550, 85705, 62301,
# ...

# %%
df["Region"].unique()
# Out:
# array(['South', 'West', 'Central', 'East'], dtype=object)

# %%
df['Product ID'].unique()
# Out:
# array(['FUR-BO-10001798', 'FUR-CH-10000454', 'OFF-LA-10000240', ...,
#        'OFF-AP-10003099', 'TEC-PH-10002645', 'OFF-ST-10001627'],
#       dtype=object)

# %%
df['Category'].unique()
# Out:
# array(['Furniture', 'Office Supplies', 'Technology'], dtype=object)

# %%
df['Sub-Category'].unique()
# Out:
# array(['Bookcases', 'Chairs', 'Labels', 'Tables', 'Storage',
#        'Furnishings', 'Art', 'Phones', 'Binders', 'Appliances', 'Paper',
#        'Accessories', 'Envelopes', 'Fasteners', 'Supplies', 'Machines',
#        'Copiers'], dtype=object)

# %%
df['Product Name'].unique()
# Out:
# array(['Bush Somerset Collection Bookcase',
#        'Hon Deluxe Fabric Upholstered Stacking Chairs, Rounded Back',
#        'Self-Adhesive Address Labels for Typewriters by Universal', ...,
#        'Eureka Hand Vacuum, Bagless', 'LG G2',
#        'Eldon Jumbo ProFile Portable File Boxes Graphite/Black'],
#       dtype=object)

# %%
df['Sales'].unique()
# Out:
# array([261.96, 731.94,  14.62, ...,  97.98,  55.6 , 243.16])

# %%
df['Quantity'].unique()
# Out:
# array([ 2,  3,  5,  7,  4,  6,  9,  1,  8, 14, 11, 13, 10, 12],
#       dtype=int64)

# %%
df['Discount'].unique()
# Out:
# array([0.  , 0.45, 0.2 , 0.8 , 0.3 , 0.5 , 0.7 , 0.6 , 0.32, 0.1 , 0.4 ,
#        0.15])

# %%
df['Profit'].unique()# there are no structural errors
# Out:
# array([ 41.9136, 219.582 ,   6.8714, ...,   4.1028,  13.32  ,  72.948 ])

# %% [markdown]
# # type casting

# %%
df["Postal Code"] =  df["Postal Code"].astype("int32")

# %%
df["Quantity"] = df["Quantity"].astype("int32")

# %%
df["Discount"] = df["Discount"].astype("float16")

# %%
df.dtypes
# Out:
# Order ID                 object
# Order Date       datetime64[ns]
# Ship Date        datetime64[ns]
# Ship Mode                object
# Customer ID              object
# Customer Name            object
# Segment                  object
# Country                  object
# City                     object
# State                    object
# Postal Code               int32
# Region                   object
# Product ID               object
# Category                 object
# Sub-Category             object
# Product Name             object
# Sales                   float64
# Quantity                  int32
# Discount                float16
# Profit                  float64
# dtype: object

# %% [markdown]
# # Data Visualization

# %% [markdown]
# ## univariate analysis

# %% [markdown]
# ## Histogram

# %%
plt.style.use("ggplot")
plt.style.use("_mpl-gallery")

# %%
df["Postal Code"].plot(kind='hist',
                      xlabel='Postal Code', 
                     title='Histogram of Postal Code',
                     color='purple',
                     figsize=(7,4))
# Out:
# <Axes: title={'center': 'Histogram of Postal Code'}, ylabel='Frequency'>

# %% [markdown]
# # conclusion

# %% [raw]
# * there are  approx 8000 to 10000 members having postal code near 2600
# * there are approx 5000 to 6000 members having postal code near 260

# %%
df["Sales"].plot(kind='hist',
                      xlabel='Sales', 
                     title='Histogram of sales',
                     color='#f542b9',
                     figsize=(7,4))
# Out:
# <Axes: title={'center': 'Histogram of sales'}, ylabel='Frequency'>

# %% [raw]
# #There is approx customers which buys the product worth 0-2500 USD
# #There is approx only 200 customers which buys the products worth 2500-5000 USD
# #There is maximum customers which are like to buy products under 2500 USD

# %%
 df["Quantity"].plot(kind='hist',
                      xlabel='Quantity', 
                     title='Histogram of quantity',
                     color='black',
                     figsize=(7,4))
# Out:
# <Axes: title={'center': 'Histogram of quantity'}, ylabel='Frequency'>

# %% [markdown]
# # conclusion

# %% [raw]
# * There is maximum customers near about 3300 customers they are buying 1-2 products from our store
# * There is minimum customers near about 100 customers they are buying 11-12 products from our store
# * We have maximum number of customers they buy 1-2 products

# %%
df["Profit"].plot(kind='hist',
                      xlabel='Profit', 
                     title='Histogram of Profit',
                     color='orange',
                     figsize=(7,4))
# Out:
# <Axes: title={'center': 'Histogram of Profit'}, ylabel='Frequency'>

# %%
df["Discount"].plot(kind = "hist",
                    color = "purple",
                    xlabel = "Discount",
                    title = "hist plot of Discount",
                    figsize = (7,4))
# Out:
# <Axes: title={'center': 'hist plot of Discount'}, ylabel='Frequency'>

# %% [markdown]
# # conclusion

# %% [raw]
# There is maximum number of customers which they are not getting discounts , we should give more discount to almost every customer to grow our buisness .
# There is only 100 customers they are getting discounts of 0.4%

# %%
df["Profit"].plot(kind = "hist",
                    color = "purple",
                    xlabel = "Profit",
                    title = "histogram plot of profit",
                    figsize = (7,4))
# Out:
# <Axes: title={'center': 'histogram plot of profit'}, ylabel='Frequency'>

# %%
df["Profit"].plot(kind = "kde",
                    color = "purple",
                    xlabel = "Profit",
                    title = "density plot of profit",
                    figsize = (7,4))
# Out:
# <Axes: title={'center': 'density plot of profit'}, ylabel='Density'>

# %% [markdown]
# # Boxplot

# %%
df['Profit'].plot(kind = "box",figsize = (5,3)) # there are so many outliers in profit
# Out:
# <Axes: >

# %%
df['Discount'].plot(kind = "box",figsize = (5,3))
# Out:
# <Axes: >

# %% [markdown]
# # conclusion

# %% [markdown]
# * discount is not normally distributed

# %% [markdown]
# # categorical

# %% [markdown]
# ## count plot

# %%
df.dtypes
# Out:
# Order ID                 object
# Order Date       datetime64[ns]
# Ship Date        datetime64[ns]
# Ship Mode                object
# Customer ID              object
# Customer Name            object
# Segment                  object
# Country                  object
# City                     object
# State                    object
# Postal Code               int32
# Region                   object
# Product ID               object
# Category                 object
# Sub-Category             object
# Product Name             object
# Sales                   float64
# Quantity                  int32
# Discount                float16
# Profit                  float64
# dtype: object

# %%
plt.style.use('classic')
plt.style.use('fivethirtyeight')
sns.countplot(data = df,x= "Country",width = 0.5,)
# Out:
# <Axes: xlabel='Country', ylabel='count'>

# %%
sns.countplot(data = df,x= "Category",width = 0.5)
# Out:
# <Axes: xlabel='Category', ylabel='count'>

# %% [markdown]
# # conclusion

# %% [raw]
# # the highest count of office supplies is 6000
# # the furniture is count is around 2100
# # for technological purpose count is 1800

# %%
sns.countplot(data=df,x='Ship Mode',color='pink',width=0.5)
# Out:
# <Axes: xlabel='Ship Mode', ylabel='count'>

# %% [raw]
# Conclusion
# There is approx 6000 customer they got standard class ship mode
# There is approx 500 customers they got ship mode as same day

# %%
sns.countplot(data=df,x='Segment',color='blue',width=0.4)
# Out:
# <Axes: xlabel='Segment', ylabel='count'>

# %% [raw]
# Conclusion
# We have near about 5200 customers from consumer segment
# we have near about 3000 customer from corporate segment
# We have near about 1800 customer from home office

# %%
sns.countplot(data=df,x='Country',color='green',width=0.2)
# Out:
# <Axes: xlabel='Country', ylabel='count'>

# %%
sns.countplot(data=df,x='Region',color='red',width=0.5)
# Out:
# <Axes: xlabel='Region', ylabel='count'>

# %% [raw]
# Most of our customer from west region near about 3300 customer
# Lowest of our customer from south region near about 1600 customer

# %% [markdown]
# # Pie Chart

# %%
(df['Ship Mode'].value_counts()/len(df['Ship Mode'])*100).plot(kind='pie',autopct="%1.1f" + "Percent",ylabel='Ship Mode')
# Out:
# <Axes: ylabel='Ship Mode'>

# %% [raw]
# We have 59.7% standard class shipping
# We have 19% of second class shipping
# We have 15.4% of first class shipping
# We have 5.4% of same day shipping

# %%
(df['Sub-Category'].value_counts()/len(df['Sub-Category'])*100).plot(kind='pie',autopct="%1.1f")
# Out:
# <Axes: ylabel='Sub-Category'>

# %% [markdown]
# # Bar plot for categrical data

# %%
df['Sub-Category'].value_counts().plot(kind='barh',
                               color = 'blue',
                               grid = True,
                               width = 0.8,
                               title = 'Bar Plot for Sub Category of Products',
                               figsize=(8,5),
                               ylabel='Category Of products')
# Out:
# <Axes: title={'center': 'Bar Plot for Sub Category of Products'}, ylabel='Category Of products'>

# %% [markdown]
# # BiVariate Analysis
# # Categrical & Categrical
# # Count Plot

# %%
sns.countplot(data=df,x='Ship Mode',hue='Segment')
# Out:
# <Axes: xlabel='Ship Mode', ylabel='count'>

# %%
sns.countplot(data=df,x='Region',hue='Category')
# Out:
# <Axes: xlabel='Region', ylabel='count'>

# %%
df['Order Date'].plot(kind='line')
# Out:
# <Axes: >

# %%
df['Ship Date'].plot(kind='line')
# Out:
# <Axes: >

# %% [markdown]
# # Scatter Plot

# %%
df.plot('Profit','Discount',kind='scatter',grid=True)
# Out:
# <Axes: xlabel='Profit', ylabel='Discount'>

# %% [markdown]
# ### conclusion
# Direction is negative
# strenghth is strong

# %%
df.plot('Quantity','Sales',kind='scatter',grid=True)
# Out:
# <Axes: xlabel='Quantity', ylabel='Sales'>

# %%
df.corr(numeric_only=True)
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.023854  0.012761  0.058413 -0.029961
# Sales          -0.023854  1.000000  0.200795 -0.028193  0.479064
# Quantity        0.012761  0.200795  1.000000  0.008625  0.066253
# Discount        0.058413 -0.028193  0.008625  1.000000 -0.219489
# Profit         -0.029961  0.479064  0.066253 -0.219489  1.000000

# %% [markdown]
# # Multivariate Analysis
# # Heatmap

# %%
sns.heatmap(df.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >

# %% [raw]
# Correaltion ranges from -0.2 to +1
# -0.2 to 0.5 indicates negative correlation
# +0.5 to 0.1 indicates positive correlation

# %%
sns.pairplot(df)

# %% [raw]
# Pair plot is for Numeric data only
# Pair plot is the combination od histogram and scatter plot in single plot
